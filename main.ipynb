# %%
import numpy as np
from main import text
from emojis import emojis
from textblob import TextBlob
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
all_points = []
emoji_list = ['happy', 'laugh', 'sad', 'angry']
for emoji in emojis:
    for i in emoji:
        sentiment = TextBlob(i).sentiment
        curr = [sentiment.polarity, sentiment.subjectivity]
        #rint(i, " polarity: ", sentiment.polarity, " subjectivity: ", sentiment.subjectivity)
        all_points.append(curr)

#for emoji in emojis:
# for i in emoji_list:
#     sentiment = TextBlob(i).sentiment
#     curr = [sentiment.polarity, sentiment.subjectivity]
#     all_points.append(curr)

# %%
X = np.array(all_points)
kmeans = KMeans(n_clusters=4, random_state=0).fit(X)

Y = np.array([[x, y]])
y_means = kmeans.predict(X)
plt.scatter(X[:, 0], X[:, 1], c=y_means, s=50, cmap="viridis")

# %%
message = TextBlob("angry")

x = message.sentiment.polarity
y = message.sentiment.subjectivity
plt.scatter(x, y)
z = kmeans.predict([[x, y]])

j = 0
for emoji in emojis:
    for i in emoji:
        print(i, ":",kmeans.labels_[j])
        j = j + 1
# Out:
# smile : 0
# happy : 3
# joy : 0
# grin : 1
# sneer : 1
# dimple : 1
# pull a face : 1
# smirk : 1
# grimace : 1
# make a face : 1
# simper : 1
# beam : 1
# prosperous : 1
# happiness : 0
# content : 1
# bright : 3
# joyous : 1
# glad : 3
# cheerful : 3
# felicitous : 3
# joyful : 1
# halcyon : 1
# euphoric : 1
# riant : 1
# golden : 0
# blessed : 1
# elated : 1
# felicity : 1
# blissful : 1
# laughing : 1
# contented : 1
# joyfulness : 1
# exhilaration : 1
# jubilation : 1
# joyousness : 1
# lightness : 1
# exultation : 1
# elation : 1
# emotion : 1
# high spirits : 0
# jubilancy : 1
# exuberance : 1
# excitement : 1
# jubilance : 1
# laugh : 0
# happy : 3
# joke : 1
# giggle : 1
# howl : 1
# express emotion : 1
# snigger : 1
# chortle : 1
# titter : 1
# cachinnate : 1
# express feelings : 1
# cackle : 1
# convulse : 1
# guffaw : 1
# express joy : 0
# express mirth : 1
# roar : 1
# chuckle : 1
# laugh loudly : 0
# laugh softly : 0
# bray : 1
# break up : 1
# bellylaugh : 1
# ...

# %%
centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5)

# %%
#figure out how to plot prediction on same plot

# %%
from main import text
from emojis import emojis, dict, emojidict
from textblob import TextBlob
from sklearn import svm
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
X = []
y = []
counter = 0
for key in emojidict:
    for i in emojidict.get(key):
        m = TextBlob(i)
        curr = [m.sentiment.polarity, m.sentiment.subjectivity]
        X.append(curr)
        y.append(counter)
    counter = counter + 1

clf = svm.SVC()
clf.fit(X, y)

message = [TextBlob(text).sentiment.polarity, TextBlob(text).sentiment.subjectivity]
# print(clf.predict([message]))

# %%
X = np.array(X)
Y = np.array([y, y])
plt.scatter(X, Y)
print(X.size)
print(Y.size)
# Out:
# 138
# 138

# %%
from main import text
from emojis import emojis, dict, emojidict
from textblob import TextBlob
from sklearn import tree
import numpy as np

# %%
X = []
Y = []
counter = 0
for key in emojidict:
    print(key, ": ", counter)
    for i in emojidict.get(key):
        m = TextBlob(i)
        curr = [m.sentiment.polarity]
        X.append(curr)
        Y.append(counter)
    counter = counter + 1

clf = tree.DecisionTreeClassifier()
clf = clf.fit(X, Y)
tree.plot_tree(clf)
# Out:
# smile :  0
# laugh :  1
# sad :  2
# angry :  3
# [Text(152.1818181818182, 195.696, 'X[0] <= -0.083\ngini = 0.709\nsamples = 69\nvalue = [9, 22, 12, 26]'),
#  Text(91.30909090909091, 152.208, 'X[0] <= -0.688\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 1, 4]'),
#  Text(60.872727272727275, 108.72, 'X[0] <= -0.825\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2]'),
#  Text(30.436363636363637, 65.232, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]'),
#  Text(91.30909090909091, 65.232, 'gini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1]'),
#  Text(121.74545454545455, 108.72, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]'),
#  Text(213.05454545454546, 152.208, 'X[0] <= 0.1\ngini = 0.714\nsamples = 64\nvalue = [9, 22, 11, 22]'),
#  Text(182.61818181818182, 108.72, 'gini = 0.721\nsamples = 60\nvalue = [9, 19, 11, 21]'),
#  Text(243.4909090909091, 108.72, 'X[0] <= 0.225\ngini = 0.375\nsamples = 4\nvalue = [0, 3, 0, 1]'),
# ...
